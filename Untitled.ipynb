# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv("C:\\Users\\admin\\Downloads\\all-ages.csv")

# %%
data.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
emp=data.Employed
emp.mean()
# Out:
# 166161.98265895955

# %%
import scipy
from scipy import stats
scipy.stats.hmean(data.loc[:,"Employed"])
# Out:
# 19515.5506262411

# %%
print(data.Unemployed.mean())
print(data.P75th.mean())
print(data.Unemployment_rate.mean())
print(data.Total.mean())
# Out:
# 9725.034682080925
# 82506.35838150288
# 0.05735545328323702
# 230256.63583815028

# %%
print(scipy.stats.hmean(data.loc[:,"Employed"]))
print(scipy.stats.hmean(data.loc[:,"Total"]))
print(scipy.stats.hmean(data.loc[:,"P25th"]))
print(scipy.stats.hmean(data.loc[:,"P75th"]))
# Out:
# 19515.5506262411
# 28293.2007113933
# 36867.91048186295
# 78039.70683420809

# %%
print(scipy.stats.mstats.gmean(emp, axis=0))
print(scipy.stats.mstats.gmean(data.Total, axis=0))
print(scipy.stats.mstats.gmean(data.P25th, axis=0))
print(scipy.stats.mstats.gmean(data.P75th, axis=0))
# Out:
# 55363.76017230626
# 76923.96538492135
# 37718.103341416594
# 80189.40202273318

# %%
print(scipy.stats.iqr(emp))
print(scipy.stats.iqr(data.Total))
print(scipy.stats.iqr(data.P25th))
print(scipy.stats.iqr(data.P75th))
print(scipy.stats.iqr(data.Unemployed))
# Out:
# 125598.0
# 181483.0
# 10000.0
# 25000.0
# 7761.0

# %%
plt.boxplot(data.P75th)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb46fb4eb8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bb46fc4860>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb46fb4d68>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb46fc4ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb46fc4fd0>],
#  'means': []}

# %%
plt.boxplot(data.Total)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb475474e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bb47547b70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb475470b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb47547f98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb47551208>],
#  'means': []}

# %%
plt.boxplot(data.Unemployed)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1bb472eb4e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1bb472ebb70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1bb472eb0b8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1bb472ebf98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1bb472f5588>],
#  'means': []}

# %%
import seaborn as sns
ax=sns.countplot(x="Major_category",data=data.sample(10))

# %%
sns.boxplot(x="Major_category",y="Employed",data=data)

# %%
m=data.Major.sample(20)
n=data.P75th.sample(20)
plt.pie(n,labels=m,autopct='%.1f%%',startangle=90)
plt.show()

# %%
plt.bar(data.Major_category.sample(20),data.P75th.sample(20))
plt.show()
