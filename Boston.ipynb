# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
boston=load_boston()
print(boston.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
input_data=boston.data
target=boston.target

# %%
scaler=StandardScaler()
input_scaled=scaler.fit_transform(input_data)

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,target,test_size=0.3) #split into 70-30 train-test data

# %%
model=Sequential()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0820 06:16:11.531860 140075595290496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
h1=model.add(Dense(15,activation="relu",input_dim=13))
h2=model.add(Dense(10,activation="relu"))
h3=model.add(Dense(8,activation="relu"))
h4=model.add(Dense(5,activation="relu"))
o=model.add(Dense(1,activation="linear"))
# Out:
# W0820 06:20:45.122205 140075595290496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0820 06:20:45.140750 140075595290496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss="mean_squared_error",optimizer="Adam",metrics=['accuracy']) #error as categorical cross entropy
# Out:
# W0820 06:24:30.126437 140075595290496 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 15)                210
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                160
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 45
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# ...
# Total params: 509
# Trainable params: 509
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,batch_size=10,epochs=150)
# Out:
# Epoch 1/150
# 354/354 [==============================] - 0s 252us/step - loss: 32.2019 - acc: 0.0056
# Epoch 2/150
# 354/354 [==============================] - 0s 121us/step - loss: 32.5507 - acc: 0.0028
# Epoch 3/150
# 354/354 [==============================] - 0s 125us/step - loss: 31.7090 - acc: 0.0169
# Epoch 4/150
# 354/354 [==============================] - 0s 123us/step - loss: 30.2288 - acc: 0.0085
# Epoch 5/150
# 354/354 [==============================] - 0s 126us/step - loss: 30.2627 - acc: 0.0113
# Epoch 6/150
# 354/354 [==============================] - 0s 127us/step - loss: 32.1029 - acc: 0.0085
# Epoch 7/150
# 354/354 [==============================] - 0s 124us/step - loss: 28.6891 - acc: 0.0056
# Epoch 8/150
# 354/354 [==============================] - 0s 125us/step - loss: 28.2990 - acc: 0.0000e+00
# Epoch 9/150
# 354/354 [==============================] - 0s 125us/step - loss: 27.4557 - acc: 0.0000e+00
# Epoch 10/150
# ...
